# %% [markdown]
# <a href="https://colab.research.google.com/github/jsdhami/Lightning-Research-Data/blob/main/Data_Visualization_for_CAPE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# installing required modules
# !pip install matplotlib
# !pip install numpy
# !pip install pandas

# %%
#importing modules
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#checking version
print(pd.__version__)
print(np.__version__)
import matplotlib
print(matplotlib.__version__)
# Out:
# 2.1.4
# 1.26.4
# 3.7.1

# %%
# https://raw.githubusercontent.com/jsdhami/Lightning-Research-Data/main/Data/IS/POWER_Point_Daily_20230801_20240801_027d72N_085d31E_LST.csv

# %%
d_df=pd.read_csv('https://raw.githubusercontent.com/jsdhami/Lightning-Research-Data/main/Data/IS/POWER_Point_Daily_20230801_20240801_027d72N_085d31E_LST.csv')
# converted month number into name[eg. 5-May]
m_data = {
    1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun',
    7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'
}
d_df['MO'] = d_df['MO'].map(m_data)
d_df.head()
# Out:
#    YEAR   MO  DY    T2M  T2MDEW   QV2M   RH2M     PS  WS10M   WD10M    PSC  \
# 0  2023  Aug   1  27.32   23.74  20.32  81.62  91.41   1.51  180.19  93.10
# 1  2023  Aug   2  26.96   23.61  20.14  82.50  91.43   1.21  126.50  93.13
# 2  2023  Aug   3  26.66   23.90  20.45  85.56  91.51   2.61  135.81  93.21
# 3  2023  Aug   4  25.32   23.21  19.59  88.56  91.77   2.51  128.75  93.48
# 4  2023  Aug   5  25.00   23.29  19.59  90.69  91.82   1.96  181.38  93.54
#
#     WSC
# 0  1.97
# 1  1.70
# 2  3.53
# 3  3.55
# 4  2.63

# %% [markdown]
# ### **This is Demo**

# %%
# only selected top one month data
s_data = d_df.head(30)
# select day and temp.
x = s_data['DY']
y = s_data['T2M']
z = s_data['WD10M']
fig, ax = plt.subplots()
fig.set_size_inches(12, 6)
ax.plot(x, y, label='Temperature')

# create twinx
ax2 = ax.twinx()
ax2.plot(x, z, alpha=.5, color='red', label='Wind Direction')
# set title and labels
ax.set_title('Daily Temperature')
ax.set_xlabel('Day')
ax.set_ylabel('Temperature')
ax2.set_ylabel('Wind Direction')
# show legend
ax.legend(loc='upper left')
ax2.legend(loc='upper right')
# show plot
plt.show()

# %% [markdown]
# # **Start Plot**
